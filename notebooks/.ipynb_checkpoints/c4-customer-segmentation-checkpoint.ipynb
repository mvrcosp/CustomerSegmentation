# %% [markdown]
# # 0.0 Customer Segmentation & Clusters Analysis

# %% [markdown]
# ## 0.1 Imports

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

from sklearn import decomposition as d
from sklearn import cluster       as c
from sklearn import mixture       as mix

from sklearn import metrics       as m
from sklearn import preprocessing as pp

from IPython.core.display import HTML

# %% [markdown]
# ## 0.2 Helper Functions

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

# %%
jupyter_settings()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 0.3 Loading Data

# %%
url = "https://raw.githubusercontent.com/mvrcosp/CustomerSegmentation/main/data/raw/marketing_campaign.csv"

dfraw = pd.read_csv(url, sep='\t')

# %% [markdown]
# ## 0.4 Data Dictionary

# %% [markdown]
# ## Attributes
#
# ### People
#
# **ID:** Customer's unique identifier
#
# **Year_Birth:** Customer's birth year
#
# **Education:** Customer's education level
#
# **Marital_Status:** Customer's marital status
#
# **Income:** Customer's yearly household income
#
# **Kidhome:** Number of children in customer's household
#
# **Teenhome:** Number of teenagers in customer's household
#
# **Dt_Customer:** Date of customer's enrollment with the company
#
# **Recency:** Number of days since customer's last purchase
#
# **Complain:** 1 if the customer complained in the last 2 years, 0 otherwise
#
# ### Products
#
# **MntWines:** Amount spent on wine in last 2 years
#
# **MntFruits:** Amount spent on fruits in last 2 years
#
# **MntMeatProducts:** Amount spent on meat in last 2 years
#
# **MntFishProducts:** Amount spent on fish in last 2 years
#
# **MntSweetProducts:** Amount spent on sweets in last 2 years
#
# **MntGoldProds:** Amount spent on gold in last 2 years
#
# ### Promotion
#
# **NumDealsPurchases:** Number of purchases made with a discount
#
# **AcceptedCmp1:** 1 if customer accepted the offer in the 1st campaign, 0 otherwise
#
# **AcceptedCmp2:** 1 if customer accepted the offer in the 2nd campaign, 0 otherwise
#
# **AcceptedCmp3:** 1 if customer accepted the offer in the 3rd campaign, 0 otherwise
#
# **AcceptedCmp4:** 1 if customer accepted the offer in the 4th campaign, 0 otherwise
#
# **AcceptedCmp5:** 1 if customer accepted the offer in the 5th campaign, 0 otherwise
#
# **Response:** 1 if customer accepted the offer in the last campaign, 0 otherwise
#
# ### Place
#
# **NumWebPurchases:** Number of purchases made through the company’s website
#
# **NumCatalogPurchases:** Number of purchases made using a catalogue
#
# **NumStorePurchases:** Number of purchases made directly in stores
#
# **NumWebVisitsMonth:** Number of visits to company’s website in the last month

# %% [markdown]
# # 1.0 First Glimpse at Data

# %%
dfraw.shape
# Out:
# (2240, 29)

# %%
dfraw.sample(20)
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  Response
# 98     4646        1951    2n Cycle        Married  78497.0        0         0  01-12-2013       44       207         26              447               75                 0           223                  1                5                    7                 12                  2             0             0             0             1             0         0              3         11         0
# 731     610        1953         PhD       Together  53593.0        1         1  07-08-2012       60       349          4               78                6                 0            43                  8                7                    2                  6                  8             0             0             0             0             0         0              3         11         0
# 375   10703        1975      Master         Single  46098.0        1         1  18-08-2012       86        57          0               27                0                 0            36                  4                3                    2                  2                  8             0             0             0             0             0         0              3         11         0
# 697    2868        1949         PhD         Single  26518.0        1         1  08-04-2013       33        20          1               28                3                 3             2                  3                2                    0                  3                  8             0             0             0             0             0         0              3         11         1
# 1025   8911        1967         PhD        Married  56320.0        0         1  08-04-2013       11       201         53              172              116                77            83                  3                5                    4                  9                  4             0             0             0             0             0         0              3         11         0
# 72     6312        1959  Graduation        Married  65031.0        0         1  17-03-2013       29       258        107              291               84                37            86                  4               10                    3                 13                  7             0             0             0             0             0         0              3         11         0
# 1041   6730        1954  Graduation        Married  38998.0        1         1  03-11-2012       92        34          1               14                0                 0             5                  3                2                    0                  3                  8             0             0             0             0             0         1              3         11         0
# 1263   8147        1960  Graduation        Married  31454.0        1         1  06-07-2013       40        28          0               11                0                 0             9                  3                2                    0                  3                  8             0             0             0             0             0         0              3         11         0
# 207    5552        1963      Master       Divorced  48721.0        1         1  13-05-2013       50        81         18              113               47                13            21                  6                4                    2                  5                  6             0             0             0             0             0         0              3         11         0
# 1132   5961        1978  Graduation        Married  42693.0        1         0  07-06-2014       29         8          4               20                6                 3            16                  1                1                    0                  3                  5             0             0             0             0             0         0              3         11         0
# 1271   7488        1963      Master         Single  64191.0        0         1  22-01-2013       30       420         15              186              151                38            15                  3                5                    3                 13                  3             0             0             0             0             0         0              3         11         0
# 1734   2499        1958    2n Cycle         Single  75342.0        0         1  06-05-2013       38       204         97               97               21               118            26                  1                5                    2                 10                  4             0             0             0             0             0         0              3         11         0
# 84      535        1987  Graduation       Divorced  81361.0        0         0  25-02-2014       18       163         23              424               27                65            76                  1                3                   10                 13                  1             0             0             0             0             0         0              3         11         0
# 543    5547        1982         PhD        Married  84169.0        0         0  07-08-2013        9      1478         19              403                0                19             0                  1                7                    6                  6                  3             0             1             1             0             0         0              3         11         1
# 214       0        1985  Graduation        Married  70951.0        0         0  04-05-2013       66       239         10              554              254                87            54                  1                3                    4                  9                  1             0             0             0             0             0         0              3         11         0
# 1363   6181        1950    2n Cycle       Together  52203.0        0         0  31-07-2012       36       488         21              238               56               108            28                  1                8                    7                 11                  6             0             0             0             0             0         0              3         11         0
# 245    7411        1964         PhD        Married  31686.0        1         1  05-06-2014       31        11          0                5                0                 0             1                  2                1                    0                  3                  6             0             0             0             0             0         0              3         11         0
# 999    9097        1956  Graduation       Divorced  46086.0        0         1  03-11-2013       34       244          8               32                7                 2            50                  4                3                    1                  8                  4             0             0             0             0             0         0              3         11         0
# 276    3445        1956  Graduation         Single  60714.0        0         0  17-01-2013       56       216        162              224              101                92           162                  2                7                    4                 10                  5             0             0             0             0             0         0              3         11         1
# 555    8692        1952  Graduation       Together  43462.0        1         1  12-09-2012       50        90         17               97               15                 6            15                  6                4                    1                  5                  8             0             0             0             0             0         0              3         11         0

# %%
dfraw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
#  15  NumDealsPurchases    2240 non-null   int64
#  16  NumWebPurchases      2240 non-null   int64
#  17  NumCatalogPurchases  2240 non-null   int64
#  18  NumStorePurchases    2240 non-null   int64
#  19  NumWebVisitsMonth    2240 non-null   int64
#  20  AcceptedCmp3         2240 non-null   int64
#  21  AcceptedCmp4         2240 non-null   int64
#  22  AcceptedCmp5         2240 non-null   int64
#  23  AcceptedCmp1         2240 non-null   int64
#  24  AcceptedCmp2         2240 non-null   int64
#  25  Complain             2240 non-null   int64
#  26  Z_CostContact        2240 non-null   int64
#  27  Z_Revenue            2240 non-null   int64
#  28  Response             2240 non-null   int64
# dtypes: float64(1), int64(25), object(3)
# memory usage: 507.6+ KB

# %%
dfraw.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# dtype: int64

# %% [markdown]
# # 2.0 First Round of Data Cleaning

# %%
df1 = dfraw.copy()

# %% [markdown]
# ## 2.1 Rename columns

# %%
df1.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response'],
#       dtype='object')

# %%
new_cols = ['ID', 'YearBirth', 'Education', 'MaritalStatus', 'Income', 'Kidhome',
       'Teenhome', 'CustomerDate', 'Recency', 'MntWines', 'MntFruits',
       'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
       'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
       'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
       'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
       'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'AcceptedCmpFnl']

df1.columns = new_cols

# %% [markdown]
# ## 2.2 Dates to Datetime

# %%
df1['YearBirth'] = pd.to_datetime(df1['YearBirth'], format='%Y')
df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# Out:
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '21-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '19-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '13-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '13-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '15-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '24-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '24-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '31-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '18-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-05-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '20-02-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '31-05-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '29-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '29-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '31-12-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '29-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '24-05-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '19-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '18-02-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '21-05-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '19-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '14-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '30-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '19-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '29-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '25-02-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '16-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '21-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '24-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '20-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '30-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '20-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-05-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '24-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '25-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '24-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '19-02-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '14-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '24-02-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '21-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '30-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '14-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '19-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '19-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '19-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '19-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '18-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '21-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '24-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '14-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-10-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '20-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '13-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '18-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '21-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '13-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '30-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '16-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '24-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '15-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-02-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '26-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '30-05-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '29-12-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '13-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '19-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-01-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '31-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '29-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '14-10-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '13-05-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '31-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '18-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '21-01-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '31-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '14-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '14-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '26-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '25-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '16-02-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '20-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '15-05-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '16-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '26-12-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-10-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '31-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '20-05-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '16-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-10-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '13-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '16-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-05-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '14-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '26-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '15-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '19-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '20-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '29-01-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '13-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-12-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '31-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '15-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '13-01-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '13-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '18-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '18-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-12-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '29-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '14-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '13-02-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '16-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '30-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '15-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '16-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '25-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '29-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '21-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '16-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '18-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '30-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '14-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '16-10-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '30-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '18-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '15-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-10-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '30-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '30-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-01-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '20-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '14-02-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-02-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '13-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '25-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '25-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '21-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '21-12-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# ...
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '21-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '30-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '21-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '26-02-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '20-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '24-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '19-02-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '31-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '26-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '26-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '31-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '15-05-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '13-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-02-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '16-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '21-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '24-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '15-10-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-02-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '16-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '16-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '25-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '30-04-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '20-11-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '14-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '15-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '25-04-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-06-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '22-02-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-09-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '24-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '23-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '25-03-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-01-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '25-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '31-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '19-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-02-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '26-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '19-05-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '15-12-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '15-07-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-01-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '26-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '14-01-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '20-06-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '24-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '28-02-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '30-11-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '27-03-2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '15-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '17-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '21-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)
# /tmp/ipykernel_7205/2122165551.py:2: UserWarning: Parsing '20-12-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['CustomerDate'] = pd.to_datetime(df1['CustomerDate'], infer_datetime_format=True)

# %% [markdown]
# ## 2.3 Drop Columns

# %%
df1 = df1.drop(labels=["Z_CostContact", "Z_Revenue"], axis=1)

# %% [markdown]
# ## 2.4 Fill NA

# %%
df1["Income"].fillna(np.median(df1["Income"]), inplace=True)

# %% [markdown]
# ## 2.4 Change dtypes

# %%
df1["ID"] = df1["ID"].astype(str)
df1["Education"] = df1["Education"].astype("category")
df1["MaritalStatus"] = df1["MaritalStatus"].astype("category")

# %%
df1.dtypes
# Out:
# ID                             object
# YearBirth              datetime64[ns]
# Education                    category
# MaritalStatus                category
# Income                        float64
# Kidhome                         int64
# Teenhome                        int64
# CustomerDate           datetime64[ns]
# Recency                         int64
# MntWines                        int64
# MntFruits                       int64
# MntMeatProducts                 int64
# MntFishProducts                 int64
# MntSweetProducts                int64
# MntGoldProds                    int64
# NumDealsPurchases               int64
# NumWebPurchases                 int64
# NumCatalogPurchases             int64
# NumStorePurchases               int64
# NumWebVisitsMonth               int64
# AcceptedCmp3                    int64
# AcceptedCmp4                    int64
# AcceptedCmp5                    int64
# AcceptedCmp1                    int64
# AcceptedCmp2                    int64
# Complain                        int64
# AcceptedCmpFnl                  int64
# dtype: object

# %% [markdown]
# # 3.0 Data Description & Exploring

# %%
df2 = df1.copy()

# %%
dfcat = df2.select_dtypes(include=["object", "category"])
dfnum = df2.select_dtypes(include=["int64", "float64", "datetime64[ns]"])

# %% [markdown]
# ## 3.1 Numerical Attributes Describe()

# %%
df2.describe().T
# Out:
#                       count          mean           std     min       25%      50%       75%       max
# Income               2216.0  52247.251354  25173.076661  1730.0  35303.00  51381.5  68522.00  666666.0
# Kidhome              2240.0      0.444196      0.538398     0.0      0.00      0.0      1.00       2.0
# Teenhome             2240.0      0.506250      0.544538     0.0      0.00      0.0      1.00       2.0
# Recency              2240.0     49.109375     28.962453     0.0     24.00     49.0     74.00      99.0
# MntWines             2240.0    303.935714    336.597393     0.0     23.75    173.5    504.25    1493.0
# MntFruits            2240.0     26.302232     39.773434     0.0      1.00      8.0     33.00     199.0
# MntMeatProducts      2240.0    166.950000    225.715373     0.0     16.00     67.0    232.00    1725.0
# MntFishProducts      2240.0     37.525446     54.628979     0.0      3.00     12.0     50.00     259.0
# MntSweetProducts     2240.0     27.062946     41.280498     0.0      1.00      8.0     33.00     263.0
# MntGoldProds         2240.0     44.021875     52.167439     0.0      9.00     24.0     56.00     362.0
# NumDealsPurchases    2240.0      2.325000      1.932238     0.0      1.00      2.0      3.00      15.0
# NumWebPurchases      2240.0      4.084821      2.778714     0.0      2.00      4.0      6.00      27.0
# NumCatalogPurchases  2240.0      2.662054      2.923101     0.0      0.00      2.0      4.00      28.0
# NumStorePurchases    2240.0      5.790179      3.250958     0.0      3.00      5.0      8.00      13.0
# NumWebVisitsMonth    2240.0      5.316518      2.426645     0.0      3.00      6.0      7.00      20.0
# AcceptedCmp3         2240.0      0.072768      0.259813     0.0      0.00      0.0      0.00       1.0
# AcceptedCmp4         2240.0      0.074554      0.262728     0.0      0.00      0.0      0.00       1.0
# AcceptedCmp5         2240.0      0.072768      0.259813     0.0      0.00      0.0      0.00       1.0
# AcceptedCmp1         2240.0      0.064286      0.245316     0.0      0.00      0.0      0.00       1.0
# AcceptedCmp2         2240.0      0.013393      0.114976     0.0      0.00      0.0      0.00       1.0
# Complain             2240.0      0.009375      0.096391     0.0      0.00      0.0      0.00       1.0
# AcceptedCmpFnl       2240.0      0.149107      0.356274     0.0      0.00      0.0      0.00       1.0

# %% [markdown]
# ## 3.2 Numerical Attributes Skew & kurtosis

# %%
dfnum.skew()
# Out:
# /tmp/ipykernel_7205/1392430659.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dfnum.skew()
# Income                  6.763487
# Kidhome                 0.635288
# Teenhome                0.407115
# Recency                -0.001987
# MntWines                1.175771
# MntFruits               2.102063
# MntMeatProducts         2.083233
# MntFishProducts         1.919769
# MntSweetProducts        2.136081
# MntGoldProds            1.886106
# NumDealsPurchases       2.418569
# NumWebPurchases         1.382794
# NumCatalogPurchases     1.880989
# NumStorePurchases       0.702237
# NumWebVisitsMonth       0.207926
# AcceptedCmp3            3.291705
# AcceptedCmp4            3.241574
# AcceptedCmp5            3.291705
# AcceptedCmp1            3.555444
# AcceptedCmp2            8.472093
# Complain               10.188972
# AcceptedCmpFnl          1.971555
# dtype: float64

# %%
dfnum.kurtosis()
# Out:
# /tmp/ipykernel_7205/1159052801.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dfnum.kurtosis()
# Income                 159.636700
# Kidhome                 -0.779661
# Teenhome                -0.986235
# Recency                 -1.201897
# MntWines                 0.598744
# MntFruits                4.050976
# MntMeatProducts          5.516724
# MntFishProducts          3.096461
# MntSweetProducts         4.376548
# MntGoldProds             3.551709
# NumDealsPurchases        8.936914
# NumWebPurchases          5.703128
# NumCatalogPurchases      8.047437
# NumStorePurchases       -0.622048
# NumWebVisitsMonth        1.821614
# AcceptedCmp3             8.843214
# AcceptedCmp4             8.515406
# AcceptedCmp5             8.843214
# AcceptedCmp1            10.650694
# AcceptedCmp2            69.838711
# Complain               101.906135
# AcceptedCmpFnl           1.888714
# dtype: float64

# %% [markdown]
# ## 3.3 Numerical Attributes Histogram

# %%
dfnum.hist()
plt.show()

# %% [markdown]
# ## 3.5 Categorical Attributes Countplot

# %%
plt.subplot(1, 2, 1)
sns.countplot(x="MaritalStatus", data=dfcat)

plt.subplot(1, 2, 2)
sns.countplot(x="Education", data=dfcat)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
dfcat["MaritalStatus"].value_counts()
# Out:
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# Absurd        2
# YOLO          2
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# ## 2.6 Year of Birth Exploration

# %%
dfnum["YearBirth"].value_counts()
# Out:
# 1976-01-01    89
# 1971-01-01    87
# 1975-01-01    83
# 1972-01-01    79
# 1978-01-01    77
# 1970-01-01    77
# 1973-01-01    74
# 1965-01-01    74
# 1969-01-01    71
# 1974-01-01    69
# 1956-01-01    55
# 1958-01-01    53
# 1979-01-01    53
# 1952-01-01    52
# 1977-01-01    52
# 1968-01-01    51
# 1959-01-01    51
# 1966-01-01    50
# 1954-01-01    50
# 1955-01-01    49
# 1960-01-01    49
# 1982-01-01    45
# 1963-01-01    45
# 1967-01-01    44
# 1962-01-01    44
# 1957-01-01    43
# 1951-01-01    43
# 1983-01-01    42
# 1986-01-01    42
# 1964-01-01    42
# 1980-01-01    39
# 1981-01-01    39
# 1984-01-01    38
# 1961-01-01    36
# 1953-01-01    35
# 1985-01-01    32
# 1989-01-01    30
# 1949-01-01    30
# 1950-01-01    29
# 1988-01-01    29
# 1987-01-01    27
# 1948-01-01    21
# 1990-01-01    18
# 1946-01-01    16
# 1947-01-01    16
# 1991-01-01    15
# 1992-01-01    13
# 1945-01-01     8
# 1943-01-01     7
# 1944-01-01     7
# 1993-01-01     5
# 1995-01-01     5
# 1994-01-01     3
# 1996-01-01     2
# 1899-01-01     1
# 1941-01-01     1
# 1893-01-01     1
# 1900-01-01     1
# 1940-01-01     1
# Name: YearBirth, dtype: int64

# %% [markdown]
# # 4.0 Second Round of Data Cleaning

# %% [markdown]
# We found some unusual values in some of the attributes. We'll be performing another round of data cleaning where we will:
#
# * Categorize marital status **"Alone"**, **"YOLO"** and **"Absurd"** as **"Single"**
# * Remove an outlier from the **"Income"** collumn
# * Filter data by year of birth > 1940

# %%
df3 = df2.copy()

# %%
df3["MaritalStatus"] = df3["MaritalStatus"].apply(lambda x: "Single" if (x == "Alone") | (x == "Absurd") | (x == "YOLO") else x)
df3["MaritalStatus"] = df3["MaritalStatus"].astype("category")

# %%
df3.MaritalStatus.value_counts()
# Out:
# Married     864
# Together    580
# Single      487
# Divorced    232
# Widow        77
# Name: MaritalStatus, dtype: int64

# %%
df3 =  df3.loc[df3["Income"] <= 200000, :]

# %%
df3.Income.max()
# Out:
# 162397.0

# %%
df3 = df3.loc[df3["YearBirth"] > "01-01-1940", :]

# %%
df3.shape
# Out:
# (2211, 27)

# %% [markdown]
# # 5.0 Feature Engineering

# %%
df4 = df3.copy()

# %%
df4.head()
# Out:
#      ID  YearBirth   Education MaritalStatus   Income  Kidhome  Teenhome CustomerDate  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Complain  AcceptedCmpFnl
# 0  5524 1957-01-01  Graduation        Single  58138.0        0         0   2012-04-09       58       635         88              546              172                88            88                  3                8                   10                  4                  7             0             0             0             0             0         0               1
# 1  2174 1954-01-01  Graduation        Single  46344.0        1         1   2014-08-03       38        11          1                6                2                 1             6                  2                1                    1                  2                  5             0             0             0             0             0         0               0
# 2  4141 1965-01-01  Graduation      Together  71613.0        0         0   2013-08-21       26       426         49              127              111                21            42                  1                8                    2                 10                  4             0             0             0             0             0         0               0
# 3  6182 1984-01-01  Graduation      Together  26646.0        1         0   2014-10-02       26        11          4               20               10                 3             5                  2                2                    0                  4                  6             0             0             0             0             0         0               0
# 4  5324 1981-01-01         PhD       Married  58293.0        1         0   2014-01-19       94       173         43              118               46                27            15                  5                5                    3                  6                  5             0             0             0             0             0         0               0

# %% [markdown]
# ## 5.1 Brainstorming for new features

# %% [markdown]
# Here I'll just brainstorm for some new features that I can create based on my original ones. These features will not be necessarily used as input to the clustering algorithm, but might bring some interesting insights when exploring the data. I've come up with:
#
# * Age when enrolled with the company;
# * Total number of children in the household (Kidhome + Teenhome)
# * Are there children in the household? (0 = False, 1 = True)
# * Total Amount spent;
# * Percentage of income spent;
# * Total purchases made (web + store + catalog + deals);
# * Total enrolled campaigns.

# %%
df4.columns
# Out:
# Index(['ID', 'YearBirth', 'Education', 'MaritalStatus', 'Income', 'Kidhome',
#        'Teenhome', 'CustomerDate', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'AcceptedCmpFnl'],
#       dtype='object')

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 3, 19, 15, 11, 1, 962907)

# %% [markdown]
# ## 5.2 Creating new features

# %%
# Age when enrolled with the company
df4["AgeEnrolled"] = df4["CustomerDate"].dt.year - df4["YearBirth"].dt.year

# Age today
df4["Age"] = df4["YearBirth"].apply(lambda x: datetime.datetime.now().year - x.year)

# Customer Loyalty (years within the company)
df4["Seniority"] = df4["CustomerDate"].apply(lambda x: datetime.datetime.now() - x)
df4["Seniority"] = df4['Seniority'].astype('timedelta64[D]')

# Number of children in the household
df4["ChildrenHome"] = df4["Kidhome"] + df4["Teenhome"]

# Children in household? 
df4["HaveChildren"] = df4["ChildrenHome"].apply(lambda x: 0 if x == 0 else 1)

# Total Amount Spent
df4["TotalMnt"] = df4['MntWines'] + df4['MntFruits'] +df4['MntMeatProducts'] + df4['MntFishProducts'] + df4['MntSweetProducts'] + df4['MntGoldProds']

# % of income spent
df4["PctIncomeSpnt"] = (df4["TotalMnt"] / df4["Income"]) * 100

# Total Purchases made
df4["TotalPurchases"] = df4['NumCatalogPurchases'] + df4['NumStorePurchases'] + df4['NumWebPurchases']

# Total Enrolled Campaigns
df4["TotalCmp"] = df4['AcceptedCmp1'] + df4['AcceptedCmp2'] + df4['AcceptedCmp3'] + df4['AcceptedCmp4'] + df4['AcceptedCmp5'] + df4['AcceptedCmpFnl']

# %%
df4.dtypes
# Out:
# ID                             object
# YearBirth              datetime64[ns]
# Education                    category
# MaritalStatus                category
# Income                        float64
# Kidhome                         int64
# Teenhome                        int64
# CustomerDate           datetime64[ns]
# Recency                         int64
# MntWines                        int64
# MntFruits                       int64
# MntMeatProducts                 int64
# MntFishProducts                 int64
# MntSweetProducts                int64
# MntGoldProds                    int64
# NumDealsPurchases               int64
# NumWebPurchases                 int64
# NumCatalogPurchases             int64
# NumStorePurchases               int64
# NumWebVisitsMonth               int64
# AcceptedCmp3                    int64
# AcceptedCmp4                    int64
# AcceptedCmp5                    int64
# AcceptedCmp1                    int64
# AcceptedCmp2                    int64
# Complain                        int64
# AcceptedCmpFnl                  int64
# AgeEnrolled                     int64
# Age                             int64
# Seniority                     float64
# ChildrenHome                    int64
# HaveChildren                    int64
# TotalMnt                        int64
# PctIncomeSpnt                 float64
# TotalPurchases                  int64
# TotalCmp                        int64
# dtype: object

# %%
df4.Seniority[0]
# Out:
# 3631.0

# %%
df4.Seniority[1]
# Out:
# 2785.0

# %%
dfnum_heat = df4.select_dtypes(include=["int64", "float64"])
sns.heatmap(dfnum_heat.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df4.TotalCmp.value_counts()
# Out:
# 0    1607
# 1     368
# 2     139
# 3      51
# 4      36
# 5      10
# Name: TotalCmp, dtype: int64

# %% [markdown]
# ## 5.3 Feature Selection

# %% [markdown]
# Since we created new columns based on the original dataset attributes, we'll be droping some of these original columns. The idea is to select only attributes that are business related (such as purchases, amountspent, deals, etc)

# %%
X = df4[["Recency", "TotalMnt", "TotalCmp", "NumDealsPurchases", "TotalPurchases", "NumWebVisitsMonth", "Seniority"]]

# %%
X.hist()
plt.show()

# %% [markdown]
# # 6.0 Rescaling Data

# %%
X.head()
# Out:
#    Recency  TotalMnt  TotalCmp  NumDealsPurchases  TotalPurchases  NumWebVisitsMonth  Seniority
# 0       58      1617         1                  3              22                  7     3631.0
# 1       38        27         0                  2               4                  5     2785.0
# 2       26       776         0                  1              20                  4     3132.0
# 3       26        53         0                  2               6                  6     2725.0
# 4       94       422         0                  5              14                  5     2981.0

# %% [markdown]
# ## 6.1 MinMaxScaler()

# %%
mm = pp.MinMaxScaler()

X["Recency"] = mm.fit_transform(X[["Recency"]])
X["TotalMnt"] = mm.fit_transform(X[["TotalMnt"]])
X["TotalCmp"] = mm.fit_transform(X[["TotalCmp"]])
X["NumDealsPurchases"] = mm.fit_transform(X[["NumDealsPurchases"]])
X["TotalPurchases"] = mm.fit_transform(X[["TotalPurchases"]])
X["NumWebVisitsMonth"] = mm.fit_transform(X[["NumWebVisitsMonth"]])
X["Seniority"] = mm.fit_transform(X[["Seniority"]])

# %% [markdown]
# ## 6.2 Standard Scaler

# %%
ss = pp.StandardScaler()

X["Recency"] = ss.fit_transform(X[["Recency"]])
X["TotalMnt"] = ss.fit_transform(X[["TotalMnt"]])
X["TotalCmp"] = ss.fit_transform(X[["TotalCmp"]])
X["NumDealsPurchases"] = ss.fit_transform(X[["NumDealsPurchases"]])
X["TotalPurchases"] = ss.fit_transform(X[["TotalPurchases"]])
X["NumWebVisitsMonth"] = ss.fit_transform(X[["NumWebVisitsMonth"]])
X["Seniority"] = ss.fit_transform(X[["Seniority"]])
# Out:
# /tmp/ipykernel_7205/4218046163.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Recency"] = ss.fit_transform(X[["Recency"]])
# /tmp/ipykernel_7205/4218046163.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["TotalMnt"] = ss.fit_transform(X[["TotalMnt"]])
# /tmp/ipykernel_7205/4218046163.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["TotalCmp"] = ss.fit_transform(X[["TotalCmp"]])
# /tmp/ipykernel_7205/4218046163.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["NumDealsPurchases"] = ss.fit_transform(X[["NumDealsPurchases"]])
# /tmp/ipykernel_7205/4218046163.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["TotalPurchases"] = ss.fit_transform(X[["TotalPurchases"]])
# /tmp/ipykernel_7205/4218046163.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["NumWebVisitsMonth"] = ss.fit_transform(X[["NumWebVisitsMonth"]])
# /tmp/ipykernel_7205/4218046163.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Seniority"] = ss.fit_transform(X[["Seniority"]])

# %%
X.head()
# Out:
#     Recency  TotalMnt  TotalCmp  NumDealsPurchases  TotalPurchases  NumWebVisitsMonth  Seniority
# 0  0.311203  1.675740  0.616913           0.350677        1.308997           0.691967   1.973091
# 1 -0.380220 -0.963539 -0.502951          -0.168992       -1.189347          -0.132576  -1.664824
# 2 -0.795074  0.279744 -0.502951          -0.688662        1.031403          -0.544847  -0.172676
# 3 -0.795074 -0.920381 -0.502951          -0.168992       -0.911753           0.279696  -1.922832
# 4  1.555764 -0.307869 -0.502951           1.390015        0.198622          -0.132576  -0.821997

# %%
X.describe()
# Out:
#             Recency      TotalMnt      TotalCmp  NumDealsPurchases  TotalPurchases  NumWebVisitsMonth     Seniority
# count  2.211000e+03  2.211000e+03  2.211000e+03       2.211000e+03    2.211000e+03       2.211000e+03  2.211000e+03
# mean   5.543583e-17  7.552128e-17 -1.606836e-17       1.446152e-17   -1.092648e-16       6.427343e-18  6.411274e-16
# std    1.000226e+00  1.000226e+00  1.000226e+00       1.000226e+00    1.000226e+00       1.000226e+00  1.000226e+00
# min   -1.693923e+00 -1.000057e+00 -5.029508e-01      -1.208331e+00   -1.744534e+00      -2.193932e+00 -2.202340e+00
# 25%   -8.642159e-01 -8.938221e-01 -5.029508e-01      -6.886617e-01   -9.117531e-01      -9.571183e-01 -7.402943e-01
# 50%    6.254389e-05 -3.493671e-01 -5.029508e-01      -1.689924e-01   -7.897173e-02       2.796956e-01  3.629151e-03
# 75%    8.643410e-01  7.312434e-01  6.169125e-01       3.506769e-01    8.232081e-01       6.919669e-01  7.475526e-01
# max    1.728619e+00  3.182951e+00  5.096366e+00       6.586708e+00    2.696966e+00       6.051494e+00  2.368704e+00

# %% [markdown]
# # 7.0 PCA

# %%
pca = d.PCA(n_components = 2)
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
X_pca = pd.DataFrame(pca.transform(X), columns=["att1", "att2"])

# %%
sns.scatterplot(x="att1", y="att2", data=X_pca)

#fig = px.scatter_3d(X_pca, x="att1", y="att2", z="att3")
#fig.show()
# Out:
# <AxesSubplot:xlabel='att1', ylabel='att2'>

# %% [markdown]
# # GMM

# %%
# GMM
GMM = mix.GaussianMixture(n_components=3, init_params="random", n_init=300, random_state=91)
GMM.fit(X_pca)
labels = GMM.predict(X_pca)

# %%
X_pca["label"] = labels

# %%
X_pca.sample(30)

# %%
fig = px.scatter_3d(X_pca, x="att1", y="att2", z="att3", color="label")
fig.show()

# %% [markdown]
# # 7.0 K-Means Clustering

# %% [markdown]
# ## 7.1 Optimal number of clusters - Elbow method with inertia

# %%
inertia = []
clusters = list(range(1, 12))

for i in clusters:
  kmeans = c.KMeans(n_clusters=i, init="k-means++", n_init=10, max_iter=300, random_state=42)
  kmeans.fit(X)
  inertia.append(kmeans.inertia_)

sns.lineplot(x=arange(1, 12), y=inertia, markers=True)

# %% [markdown]
# ## 7.2 Optimal number of clusters - Elbow method with distortion

# %%
model = c.KMeans()
visualizer = KElbowVisualizer(model, k=(1,12))

# %%
visualizer.fit(X)
visualizer.show()

# %%
model = c.KMeans()
visualizer1 = KElbowVisualizer(model, k=(2,12), metric='calinski_harabasz', timings=False)

# %%
visualizer1.fit(X_pca)
visualizer1.show()

# %% [markdown]
# ## Final Model

# %%
kmns = c.KMeans(n_clusters = 3, random_state = 42)
kmns.fit(X)

# %%
df5 = df4.copy()
df5["Label"] = kmns.labels_

# %%
df5.head()

# %%
df5["Label"] = df5["Label"].astype("int64")

# %%
df5.Label.value_counts()

# %%
X.head()

# %%
#fig = px.scatter_3d(X_pca, x="att1", y="att2", z="att3", color="Label")
#fig.show()

# %% [markdown]
# ## Clusters Overview

# %%
clusterdf = X.copy()
clusterdf["label"] = kmns.labels_
polar = clusterdf.groupby("label").mean().reset_index()
polar = pd.melt(polar, id_vars="label")
fig = px.line_polar(polar, r="value", theta="variable", color="label", line_close=True)
fig.show()

# %%
df5.dtypes

# %%
df5_1 = df5.select_dtypes(include=["int64", "float64"])
df5_2 = df5[["Education", "MaritalStatus", "Label"]]

# %%
df5_1[["TotalMnt", "Recency", "TotalPurchases", "TotalCmp", "NumWebVisitsMonth", "Label"]].groupby("Label").mean().sort_values(by="TotalMnt", ascending=False)

# %%
df5_1[['Income', 'ChildrenHome', 'PctIncomeSpnt', 'Complain', 'AgeEnrolled', 'Label']].groupby("Label").mean()

# %%
df5_2.groupby("Label")["Education"].value_counts()

# %%
df5_2.groupby("Label")["MaritalStatus"].value_counts()

# %%
cluster_zero = df5[["Income", "Cluster"]].groupby("Cluster").mean().reset_index().sort_values(by="Income", ascending=False)
